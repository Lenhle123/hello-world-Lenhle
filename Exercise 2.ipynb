# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (3.10.7)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dlenh\abili_tech\ds_onboarding_venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
print(df.head())
print(df.info())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="petal_length",
    y="petal_width",
    hue="species",
    palette="viridis",
    s=60,
    edgecolor="k"
)
plt.title("Scatter plot: Petal Length vs Petal Width by Species")
plt.xlabel("Petal Lenght (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend(title="Species")
plt.show()

# %%
sns.pairplot(
    df,
    vars=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    hue="species",
    palette="viridis",
    diag_kind="kde"
)
plt.suptitle("Pairplot of Iris Features Colored by Species", y=1.02)
plt.show()
